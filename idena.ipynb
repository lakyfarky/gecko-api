# %%
import requests
import time
from datetime import datetime
import numpy as np

def fetch_token_price(token_address):
    url = f"https://api.geckoterminal.com/api/v2/simple/networks/bsc/token_price/{token_address}"
    headers = {'accept': 'application/json'}
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        data = response.json()
        return data
    else:
        print(f"Error fetching token price. Status code: {response.status_code}")
        return None

def main():
    token_address = "0x0de08c1abe5fb86dd7fd2ac90400ace305138d5b"
    token_name = "Idena"  # Enter the token name manually here

    while True:
        price_data = fetch_token_price(token_address)
        
        if price_data:
            price = float(price_data["data"]["attributes"]["token_prices"][token_address])
            price = round(price, 5)
            now = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            print(f"Price of {token_name} at {now} is {price}")

            # Save to a file
            with open(f"{token_name}.txt", "a") as file:
                file.write(f"{now}, {token_name}, {price}\n")
        
        time.sleep(4)  # Pause for 1 minute

if __name__ == "__main__":
    main()
# Out:
# Price of Idena at 2024-03-09 19:18:35 is 0.04559
# Price of Idena at 2024-03-09 19:18:39 is 0.04559
# Price of Idena at 2024-03-09 19:18:43 is 0.04559
# Price of Idena at 2024-03-09 19:18:47 is 0.04559
# Price of Idena at 2024-03-09 19:18:52 is 0.04559
# Price of Idena at 2024-03-09 19:18:56 is 0.04559
# Price of Idena at 2024-03-09 19:19:00 is 0.04559
# Price of Idena at 2024-03-09 19:19:04 is 0.04559
# Price of Idena at 2024-03-09 19:19:08 is 0.04559
# Price of Idena at 2024-03-09 19:19:12 is 0.04559
# Price of Idena at 2024-03-09 19:19:16 is 0.04559
# Price of Idena at 2024-03-09 19:19:20 is 0.04559
# Price of Idena at 2024-03-09 19:19:24 is 0.04559
# Price of Idena at 2024-03-09 19:19:28 is 0.04559
# Price of Idena at 2024-03-09 19:19:33 is 0.04559
# Price of Idena at 2024-03-09 19:19:37 is 0.04559
# Price of Idena at 2024-03-09 19:19:41 is 0.04559
# Price of Idena at 2024-03-09 19:19:45 is 0.04559
# Price of Idena at 2024-03-09 19:19:49 is 0.04559
# Price of Idena at 2024-03-09 19:19:53 is 0.04559
# Price of Idena at 2024-03-09 19:19:57 is 0.04559
# Price of Idena at 2024-03-09 19:20:01 is 0.04559
# Price of Idena at 2024-03-09 19:20:05 is 0.04559
# Price of Idena at 2024-03-09 19:20:10 is 0.04559
# Price of Idena at 2024-03-09 19:20:14 is 0.04559
# Price of Idena at 2024-03-09 19:20:18 is 0.04559
# Price of Idena at 2024-03-09 19:20:22 is 0.04559
# Price of Idena at 2024-03-09 19:20:26 is 0.04559
# Price of Idena at 2024-03-09 19:20:30 is 0.04559
# Price of Idena at 2024-03-09 19:20:34 is 0.04559
# Price of Idena at 2024-03-09 19:20:38 is 0.04559
# Price of Idena at 2024-03-09 19:20:43 is 0.04559
# Price of Idena at 2024-03-09 19:20:47 is 0.04559
# Price of Idena at 2024-03-09 19:20:51 is 0.04559
# Price of Idena at 2024-03-09 19:20:55 is 0.04559
# Price of Idena at 2024-03-09 19:20:59 is 0.04559
# Price of Idena at 2024-03-09 19:21:03 is 0.04559
# Price of Idena at 2024-03-09 19:21:07 is 0.04559
# Price of Idena at 2024-03-09 19:21:11 is 0.04559
# Price of Idena at 2024-03-09 19:21:15 is 0.04559
# Price of Idena at 2024-03-09 19:21:19 is 0.04559
# Price of Idena at 2024-03-09 19:21:24 is 0.04559
# Price of Idena at 2024-03-09 19:21:28 is 0.04559
# Price of Idena at 2024-03-09 19:21:32 is 0.04559
# Price of Idena at 2024-03-09 19:21:36 is 0.04559
# Price of Idena at 2024-03-09 19:21:40 is 0.04559
# Price of Idena at 2024-03-09 19:21:44 is 0.04559
# Price of Idena at 2024-03-09 19:21:48 is 0.04559
# Price of Idena at 2024-03-09 19:21:52 is 0.04559
# Price of Idena at 2024-03-09 19:21:57 is 0.04559
# Price of Idena at 2024-03-09 19:22:01 is 0.04559
# Price of Idena at 2024-03-09 19:22:05 is 0.04559
# Price of Idena at 2024-03-09 19:22:09 is 0.04559
# Price of Idena at 2024-03-09 19:22:13 is 0.04559
# Price of Idena at 2024-03-09 19:22:17 is 0.04559
# Price of Idena at 2024-03-09 19:22:21 is 0.04559
# Price of Idena at 2024-03-09 19:22:25 is 0.04559
# Price of Idena at 2024-03-09 19:22:29 is 0.04559
# Price of Idena at 2024-03-09 19:22:33 is 0.04559
# Price of Idena at 2024-03-09 19:22:37 is 0.04559
# Price of Idena at 2024-03-09 19:22:42 is 0.04559
# Price of Idena at 2024-03-09 19:22:46 is 0.04559
# Price of Idena at 2024-03-09 19:22:50 is 0.04559
# Price of Idena at 2024-03-09 19:22:54 is 0.04559
# Price of Idena at 2024-03-09 19:22:58 is 0.04559
# Price of Idena at 2024-03-09 19:23:02 is 0.04559
# Price of Idena at 2024-03-09 19:23:06 is 0.04559
# Price of Idena at 2024-03-09 19:23:11 is 0.04559
# Price of Idena at 2024-03-09 19:23:15 is 0.04559
# Price of Idena at 2024-03-09 19:23:19 is 0.04559
# Price of Idena at 2024-03-09 19:23:23 is 0.04559
# Price of Idena at 2024-03-09 19:23:27 is 0.04559
# Price of Idena at 2024-03-09 19:23:31 is 0.04559
# Price of Idena at 2024-03-09 19:23:35 is 0.04559
# Price of Idena at 2024-03-09 19:23:39 is 0.04559
# Price of Idena at 2024-03-09 19:23:44 is 0.04559
# Price of Idena at 2024-03-09 19:23:48 is 0.04559
# Price of Idena at 2024-03-09 19:23:52 is 0.04559
# Price of Idena at 2024-03-09 19:23:56 is 0.04559
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 37
#      34         time.sleep(4)  # Pause for 1 minute
#      36 if __name__ == "__main__":
# ---> 37     main()
#
# Cell In[13], line 34, in main()
#      31     with open(f"{token_name}.txt", "a") as file:
#      32         file.write(f"{now}, {token_name}, {price}\n")
# ---> 34 time.sleep(4)
#
# KeyboardInterrupt:
